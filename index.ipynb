# %% [markdown]
# # Virtuous Interview Exam
#
# > Monday August 14th, 2023

# %% [markdown]
# # Requirements
#
# > Virtuous Data Schema, changes that require ETL have been highlighted <br>
#
# <br>
#
# ![alternative text](images/virtuous_requirements.png)

# %% [markdown]
# ## Summary
# > I performed ETL of 3 spreadsheets into SQL tables & csv files that match the Virtuous schema <br>
# <br>
#
# - Contacts: A table of contacts, with 1 or 2 constituents per row
# - Gifts: Donations from individual constituents
# - Contact Methods: Contact information for individual constituents

# %% [markdown]
# ## Notebooks
# > I've demonstrated 3 methods of performing the data migraiton <br>
# <br>
#
# - [Setup](/00_Setup.ipynb)
# - Method 1: [SQL](01_SQL_Solution.ipynb)
# - Method 2: [Python / Pandas](02_Pandas_Solution.ipynb)
# - Method 3: [Generative AI / Chat GPT](03_Gpt_Solution.ipynb)

# %% [markdown]
# ## Result
# > CSV files generated from the Python ETL process <br>
# <br>
#
# - [final_contacts](data/final_contacts.csv)
# - [final_gifts](data/final_gifts.csv)
# - [final_contact_methods](data/final_contact_methods.csv)
# <br>
# <br>
# The intial datasets are also available in the [data folder](data/)

# %% [markdown]
# # Final Results

# %%
import pandas as pd

# %%
final_contacts = pd.read_csv('data/final_contacts.csv')
final_contact_methods = pd.read_csv('data/final_contact_methods.csv')
final_gifts = pd.read_csv('data/final_gifts.csv')

# %%
final_contacts
# Out:
#    LegacyContactId  LegacyIndividualId    ContactName  FirstName     LastName  \
# 0      653377813-7                   0            NaN     Karita      Lumbers
# 1      390551098-7                   2            NaN      Helga       Benech
# 2      093004505-X                   3            NaN      Masha          NaN
# 3      729707142-0                   4  A Company Co.        NaN          NaN
# 4      488464926-5                   5            NaN       Hoyt     Castille
# 5      315297729-8                   6            NaN   Benedict        Oscar
# 6      848348568-0                   8            NaN     Mannie       Turpin
# 7      029456846-8                   9            NaN        NaN          NaN
# 8      687119652-8                  10            NaN   Ruggiero    Makepeace
# 9      739131380-7                  11            NaN  Rosemaria       Dimond
# 10     809975531-Y                  13            NaN    Adeline  Shakespeare
#
#     SecondaryLegacyIndividualId SecondaryFirstName SecondaryLastName  \
# 0                           1.0             Kelvin               NaN
# 1                           NaN                NaN               NaN
# 2                           NaN                NaN               NaN
# 3                           NaN                NaN               NaN
# 4                           NaN                NaN               NaN
# 5                           7.0              Idell           Mouncey
# 6                           NaN                NaN               NaN
# 7                           NaN                NaN               NaN
# 8                           NaN                NaN               NaN
# 9                          12.0            Rogelio               NaN
# 10                          NaN                NaN               NaN
#
#         HomePhone                     HomeEmail               Address1  \
# 0             NaN           kklumbers@ yahoo.co      4 Bunting Parkway
# 1             NaN        ebenech1@goodreads.com      48684 Jenifer Way
# 2   577-374-96523                           NaN    353 Schmedeman Park
# 3             NaN                           NaN  2055 Lakewood Parkway
# 4             NaN  fcastille4@timesonline.co.uk           37 8th Trail
# 5             NaN                           NaN       4225 Madison Ave
# 6    702-844-9524                           NaN                    NaN
# 7             NaN       jdoley6@telegraph.co.uk    608 Old Shore Alley
# 8             NaN          cmakepeace7@1688.com     15 Sunbrook Center
# 9             NaN                           NaN                    NaN
# 10            NaN                           NaN                    NaN
#
#             City State  PostalCode  IsPrivate  IsDeceased
# 0     Washington    DC         NaN       True       False
# 1      Las Vegas    NV     89130.0      False       False
# 2   Indianapolis    IN         NaN      False       False
# 3         Camden    NJ         NaN      False       False
# 4   Grand Rapids    MI     49560.0      False       False
# 5          Boise    ID         NaN      False       False
# 6            NaN    NV         NaN      False        True
# 7       Marietta    GA     30066.0      False       False
# 8          Omaha    NE     68164.0      False       False
# 9         Juneau    AK         NaN      False       False
# 10           NaN   NaN         NaN      False       False

# %%
final_contact_methods
# Out:
#    LegacyContactId       Type                         Value
# 0      093004505-X  HomePhone                  818-323-9865
# 1      653377813-7  HomePhone                  832-442-4988
# 2      848348568-0  HomePhone                  702-844-9524
# 3      029456846-8  HomeEmail       jdoley6@telegraph.co.uk
# 4      315297729-8  HomeEmail             dmouncey9@cnn.com
# 5      390551098-7  HomeEmail        ebenech1@goodreads.com
# 6      488464926-5  HomeEmail  fcastille4@timesonline.co.uk
# 7      653377813-7  HomeEmail           kklumbers@ yahoo.co
# 8      687119652-8  HomeEmail          cmakepeace7@1688.com
# 9      093004505-X        Fax                  818-156-7985
# 10     739131380-7        Fax                  626-981-3874

# %%
final_gifts
# Out:
#    LegacyContactId  LegacyGiftId               GiftType    GiftDate  \
# 0      848348568-0      95196378                  Other  2019-03-04
# 1      729707142-0      95196889                  Check  2019-03-05
# 2      687119652-8      95197689                   Cash  2019-03-07
# 3      653377813-7      95198998                 Credit  2019-03-10
# 4      390551098-7      95198999                   Cash  2019-01-10
# 5      848348568-0      95296677                  Other  2019-03-20
# 6      029456846-8      95298831                  Check  2019-03-24
# 7      093004505-X      95298845                  Check  2019-04-09
# 8      315297729-8      95298997                  Check  2019-04-12
# 9      809975531-Y             0                 Credit  2019-08-14
# 10     739131380-7      95329966                 Credit  2019-04-13
# 11     739131380-7      95330011                  Other  2019-04-13
# 12     029456846-8      95330012                  Check  2019-04-17
# 13     315297729-8      95330110  Reversing Transaction  2019-04-19
# 14     739131380-7      95330662                  Other  2019-05-10
# 15     687119652-8      95419562                  Other  2019-06-04
# 16     488464926-5      95422266                   Cash  2019-06-05
# 17     848348568-0      95485564                  Other  2019-06-10
# 18     390551098-7      95496635                  Other  2019-06-11
# 19     729707142-0      95497782                  Other  2019-06-20
# 20     315297729-8             0                  Check  2019-06-20
# 21     390551098-7      95763575                 Credit  2019-07-01
# 22     488464926-5      95798342                   Cash  2019-07-18
# 23     848348568-0      95798343                  Other  2019-07-01
# 24     029456846-8      95801563                  Other  2019-08-01
# 25     729707142-0      95801564                   Cash  2019-08-03
# 26     687119652-8      95835492  Reversing Transaction  2019-08-12
# 27     809975531-Y             0                 Credit  2019-08-14
# 28     653377813-7             0                   Cash  2019-08-26
# 29     739131380-7      96638462                  Other  2019-09-01
# 30     093004505-X      96638468                 Credit  2019-09-06
#
#     GiftAmount                      Notes CreditCardType        Project1Code  \
# 0       4.1500                        NaN            NaN                 NaN
# 1       2.3648                        NaN            NaN    ChildSponsorship
# 2       1.3100                        NaN            NaN                 NaN
# 3       2.0400  In honor of Mannie Turpin           AMEX                 NaN
# 4       5.8000                        NaN            NaN                 NaN
# 5       9.2800                        NaN            NaN             General
# 6       5.0000            ACH check #7687            NaN                 NaN
# 7       4.8300                        NaN            NaN                 NaN
# 8       7.0000                        NaN            NaN  SchoolSupplies2019
# 9       8.4800                        NaN           AMEX                 NaN
# 10      5.8400                        NaN           Visa                 NaN
# 11      7.4500                        NaN            NaN                 NaN
# 12      8.1300                        NaN            NaN      Mentorship2023
# 13     -3.0100                        NaN            NaN                 NaN
# 14      3.4000                        NaN            NaN                 NaN
# 15      5.0700                        NaN            NaN                 NaN
# 16      5.4200                        NaN            NaN         GeneralFund
# 17      6.8000                        NaN            NaN                 NaN
# 18      6.7800                        NaN            NaN                 NaN
# 19      5.2700                        NaN            NaN                 NaN
# 20      5.5900                        NaN            NaN                 NaN
# 21      4.2100                        NaN     Mastercard                 NaN
# 22      9.2800                        NaN            NaN                 NaN
# 23      2.7400                        NaN            NaN                 NaN
# 24      9.0000                        NaN            NaN                 NaN
# 25      1.8800                        NaN            NaN                 NaN
# 26     -6.7600                        NaN            NaN                 NaN
# 27      7.5800                        NaN     Mastercard           Color run
# 28      5.4900                        NaN            NaN                 NaN
# 29      8.9300                        NaN            NaN          ReliefFund
# 30      2.6200                        NaN       Discover                 NaN
#
#         Project1Code.1  LegacyPledgeID
# 0                  NaN               0
# 1     ChildSponsorship               1
# 2                  NaN               2
# 3                  NaN               3
# 4                  NaN        89752384
# 5              General               5
# 6                  NaN               6
# 7                  NaN               7
# 8   SchoolSupplies2019               8
# 9                  NaN               9
# 10                 NaN              10
# 11                 NaN              11
# 12      Mentorship2023              12
# 13                 NaN              13
# 14                 NaN              14
# 15                 NaN              15
# 16         GeneralFund              16
# 17                 NaN        57398862
# 18                 NaN              18
# 19                 NaN              19
# 20                 NaN        65139856
# 21                 NaN              21
# 22                 NaN              22
# 23                 NaN              23
# 24                 NaN              24
# 25                 NaN              25
# 26                 NaN              26
# 27           Color run              27
# 28                 NaN              28
# 29          ReliefFund              29
# 30                 NaN              30
